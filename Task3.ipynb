# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Task3.csv')
df.head(3)
# Out:
#               DateTime  Active Energy  Inside Temperature  \
# 0  2019-07-19 16:30:17         1.9375                  28
# 1  2019-07-19 16:30:34         1.9375                  28
# 2  2019-07-19 16:30:35         1.9375                  28
#
#    Outside Temperature  Difference Of Temperature  Inside Humidity  \
# 0                24.54                       3.46               42
# 1                24.54                       3.46               42
# 2                24.54                       3.46               42
#
#    Outside Humidity  Difference Of Humidity  No Of People
# 0             44.04                    2.04            79
# 1             44.04                    2.04            79
# 2             43.84                    1.84            79

# %% [markdown]
# ## 2.  Explain Active Energy behaviour based on other variables?

# %%
df.corr()
# Out:
#                            Active Energy  Inside Temperature  \
# Active Energy                   1.000000           -0.493567
# Inside Temperature             -0.493567            1.000000
# Outside Temperature             0.185670            0.004300
# Difference Of Temperature      -0.340607            0.331067
# Inside Humidity                -0.699079            0.660782
# Outside Humidity               -0.139779           -0.014555
# Difference Of Humidity         -0.336388            0.333266
# No Of People                    0.064551           -0.037339
#
#                            Outside Temperature  Difference Of Temperature  \
# Active Energy                         0.185670                  -0.340607
# Inside Temperature                    0.004300                   0.331067
# Outside Temperature                   1.000000                  -0.942175
# Difference Of Temperature            -0.942175                   1.000000
# ...

# %%
dat = df[['Active Energy','Inside Temperature','Outside Temperature','Difference Of Temperature','Inside Humidity','Outside Humidity','Difference Of Humidity','No Of People']]

sns.pairplot(dat, kind="scatter")
plt.show()

# %% [markdown]
# ### 2. Active Energy behaviour

# %%
plt.scatter(df['Active Energy'], df['Inside Temperature'], df['Outside Temperature'], df['Inside Humidity'])
plt.show()

# %%
np.corrcoef(df['Active Energy'], df['Inside Temperature'])
# Out:
# array([[ 1.        , -0.49356724],
#        [-0.49356724,  1.        ]])

# %% [markdown]
# #### Active Energy Inside Temperature

# %%
from scipy.stats import linregress
linregress(df['Active Energy'], df['Inside Temperature'])
# Out:
# LinregressResult(slope=-1.0495407713677432, intercept=30.398287371220302, rvalue=-0.4935672368476804, pvalue=0.0, stderr=0.013833742872236099)

# %%
linregress(df['Active Energy'], df['Inside Temperature'])
# Out:
# LinregressResult(slope=-1.0495407713677432, intercept=30.398287371220302, rvalue=-0.4935672368476804, pvalue=0.0, stderr=0.013833742872236099)

# %%
pd.crosstab(df['Active Energy'], df['Inside Temperature'])
# Out:
# Inside Temperature  27    28   29   30   31   32
# Active Energy
# 0.0000               0     3    0    0    0    0
# 0.2500               0     0    0    0    5    0
# 0.3125               0     0    0    0   14   69
# 0.3750               0     0    0  195  116   26
# 0.4375               0     2    0   37  119   14
# 0.5000               0    18   54  223  318  124
# 0.5625               0    14   33   69   25   11
# 0.6250               0    24   35   52   56    0
# 0.6875               0    63   64  101   11    0
# 0.7500               0     0  141   77   12    0
# 0.8125               0    21  238  140   32    0
# 0.8750               0    80   51   71  101    0
# 0.9375               0    14   50   54   23    0
# 1.0000               0   148   83   25   75   15
# 1.0625               0   144   26    7    2    5
# 1.1250               0   150   49   71   17    7
# 1.1875               0   284  114   70   35    7
# 1.2500               0   222   89    5   12    0
# ...

# %% [markdown]
# ### Outside Temperature

# %%
np.corrcoef(df['Active Energy'], df['Outside Temperature'])
# Out:
# array([[1.        , 0.18566959],
#        [0.18566959, 1.        ]])

# %%
from scipy.stats import linregress
linregress(df['Active Energy'], df['Outside Temperature'])
# Out:
# LinregressResult(slope=1.1116885662586933, intercept=22.62315805294705, rvalue=0.18566959313434667, pvalue=2.293594576342757e-138, stderr=0.044008639447361976)

# %%
linregress(df['Active Energy'], df['Outside Temperature'])
# Out:
# LinregressResult(slope=1.1116885662586933, intercept=22.62315805294705, rvalue=0.18566959313434667, pvalue=2.293594576342757e-138, stderr=0.044008639447361976)

# %%
pd.crosstab(df['Active Energy'], df['Outside Temperature'])
# Out:
# Outside Temperature  17.68  17.72  17.74  17.76  17.78  17.80  17.82  17.86  \
# Active Energy
# 0.0000                   0      0      0      0      0      0      0      0
# 0.2500                   0      0      0      0      0      0      0      0
# 0.3125                   0      0      0      0      0      0      0      0
# 0.3750                   0      0      0      0      0      0      0      0
# 0.4375                   0      0      0      0      0      0      0      0
# 0.5000                   0      0      0      0      0      0      0      0
# 0.5625                   0      0      0      0      0      0      0      0
# 0.6250                   0      0      0      0      0      0      0      0
# 0.6875                   0      0      0      0      0      0      0      0
# 0.7500                   0      0      0      0      0      0      0      0
# 0.8125                   0      0      0      0      0      0      0      0
# ...

# %% [markdown]
# ## 1. Is there a valid case for one or more components to depend on each other?

# %%
dat=df
dat.corr()
# Out:
#                            Active Energy  Inside Temperature  \
# Active Energy                   1.000000           -0.493567
# Inside Temperature             -0.493567            1.000000
# Outside Temperature             0.185670            0.004300
# Difference Of Temperature      -0.340607            0.331067
# Inside Humidity                -0.699079            0.660782
# Outside Humidity               -0.139779           -0.014555
# Difference Of Humidity         -0.336388            0.333266
# No Of People                    0.064551           -0.037339
#
#                            Outside Temperature  Difference Of Temperature  \
# Active Energy                         0.185670                  -0.340607
# Inside Temperature                    0.004300                   0.331067
# Outside Temperature                   1.000000                  -0.942175
# Difference Of Temperature            -0.942175                   1.000000
# ...

# %%
df = dat[['Active Energy','Inside Temperature','Outside Temperature','Difference Of Temperature','Inside Humidity','Outside Humidity','Difference Of Humidity','No Of People']]
sns.pairplot(df, kind="scatter")
plt.show()

# %% [markdown]
# ### Corelations Test

# %%
plt.scatter(dat['Active Energy'], dat['Difference Of Temperature'], dat['Difference Of Humidity'], dat['No Of People'])
plt.show()

# %% [markdown]
# #### linear relationship between the two variables Active Energy , Difference Of Temperature

# %%
np.corrcoef(dat['Active Energy'], dat['Difference Of Temperature'])
# Out:
# array([[ 1.        , -0.34060723],
#        [-0.34060723,  1.        ]])

# %%
from scipy.stats import linregress
linregress(dat['Active Energy'], dat['Difference Of Temperature'])
# Out:
# LinregressResult(slope=-2.161229337626436, intercept=7.775129318273255, rvalue=-0.34060722804022625, pvalue=0.0, stderr=0.04462551959941579)

# %% [markdown]
# #### Let us consider another example of correlation between Active Energy and Difference Of Temperature using the line of code below.

# %%
linregress(dat['Active Energy'], dat['Difference Of Temperature'])
# Out:
# LinregressResult(slope=-2.161229337626436, intercept=7.775129318273255, rvalue=-0.34060722804022625, pvalue=0.0, stderr=0.04462551959941579)

# %% [markdown]
# ### Relationship Between Categorical Variables Frequency Table

# %%
pd.crosstab(dat['Active Energy'], dat['Difference Of Temperature'])
# Out:
# Difference Of Temperature  -2.76   -2.74   -2.72   -2.68   -2.66   -2.64   \
# Active Energy
# 0.0000                          0       0       0       0       0       0
# 0.2500                          0       0       0       0       0       0
# 0.3125                          0       0       0       0       0       0
# 0.3750                          0       0       0       0       0       0
# 0.4375                          0       0       0       0       0       0
# 0.5000                          0       0       0       0       0       0
# 0.5625                          0       0       0       0       0       0
# 0.6250                          0       0       0       0       0       0
# 0.6875                          0       0       0       0       0       0
# 0.7500                          0       0       0       0       0       0
# 0.8125                          0       0       0       0       0       0
# ...
